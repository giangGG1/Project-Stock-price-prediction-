# %%
import pandas as pd

# Load the data
data = data = pd.read_csv("C:/Users/admin/OneDrive/maytinh/Downloads/META_stock_data.csv")

# %%
data.head()
# Out:
#                         Date        Open        High         Low       Close  \
# 0  2023-04-10 00:00:00-04:00  214.482434  215.431424  210.436723  214.522385
# 1  2023-04-11 00:00:00-04:00  215.251614  215.791050  213.183816  213.623352
# 2  2023-04-12 00:00:00-04:00  214.612284  216.610164  212.354685  213.773178
# 3  2023-04-13 00:00:00-04:00  215.501341  220.915595  215.461391  220.116455
# 4  2023-04-14 00:00:00-04:00  217.649075  221.874587  217.319423  221.255249
#
#      Volume  Dividends  Stock Splits
# 0  16106100        0.0           0.0
# 1  16710100        0.0           0.0
# 2  18972200        0.0           0.0
# 3  23310400        0.0           0.0
# 4  21591200        0.0           0.0

# %%
data['MA21'] = data['Close'].rolling(window=21).mean()

# %%
def calculate_rsi(data, window=21):
    delta = data.diff(1)
    gain = delta.where(delta > 0, 0)
    loss = -delta.where(delta < 0, 0)
    
    avg_gain = gain.rolling(window=window, min_periods=1).mean()
    avg_loss = loss.rolling(window=window, min_periods=1).mean()
    
    rs = avg_gain / avg_loss
    rsi = 100 - (100 / (1 + rs))
    
    return rsi

data['RSI'] = calculate_rsi(data['Close'])

# %%
data = data.dropna()  # Loại bỏ các hàng chứa giá trị NaN do tính RSI và MA

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 231 entries, 20 to 250
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Date          231 non-null    object
#  1   Open          231 non-null    float64
#  2   High          231 non-null    float64
#  3   Low           231 non-null    float64
#  4   Close         231 non-null    float64
#  5   Volume        231 non-null    int64
#  6   Dividends     231 non-null    float64
#  7   Stock Splits  231 non-null    float64
#  8   MA21          231 non-null    float64
#  9   RSI           231 non-null    float64
# dtypes: float64(8), int64(1), object(1)
# memory usage: 19.9+ KB

# %%
import numpy as np

# Tính toán số lượng dòng cho từng phần
total_rows = len(data)
train_size = int(0.8 * total_rows)
val_size = int(0.1 * total_rows)
test_size = total_rows - train_size - val_size 
data.replace([np.inf, -np.inf], np.nan, inplace=True)
data.dropna(how='any', axis=0, inplace=True)

# Chia DataFrame thành các tập huấn luyện, kiểm tra và kiểm định
data_train = data.iloc[:train_size]
data_val = data.iloc[train_size:train_size + val_size]
data_test = data.iloc[train_size + val_size:]

data_train
# Out:
#                           Date        Open        High         Low  \
# 20   2023-05-08 00:00:00-04:00  231.174721  235.370266  230.025946
# 21   2023-05-09 00:00:00-04:00  231.214686  235.630000  230.835084
# 22   2023-05-10 00:00:00-04:00  235.919683  236.499070  230.475463
# 23   2023-05-11 00:00:00-04:00  232.802999  237.957533  232.053794
# 24   2023-05-12 00:00:00-04:00  236.489082  236.708850  231.204680
# ..                         ...         ...         ...         ...
# 199  2024-01-24 00:00:00-05:00  389.586649  395.730125  387.398968
# 200  2024-01-25 00:00:00-05:00  389.756486  395.070824  385.251256
# 201  2024-01-26 00:00:00-05:00  393.932028  396.369445  391.174944
# 202  2024-01-29 00:00:00-05:00  394.571333  402.502919  392.683352
# 203  2024-01-30 00:00:00-05:00  403.162244  405.929297  399.146515
#
#           Close    Volume  Dividends  Stock Splits        MA21        RSI
# 20   233.022766  16400500        0.0           0.0  223.119932  63.420304
# 21   233.122650  16865600        0.0           0.0  224.005659  63.473236
# 22   232.832962  19119000        0.0           0.0  224.920402  64.038547
# 23   235.540085  20449000        0.0           0.0  225.956922  65.334278
# 24   233.562180  16155300        0.0           0.0  226.597194  60.092979
# ..          ...       ...        ...           ...         ...        ...
# 199  390.285919  15698500        0.0           0.0  363.993324  70.999208
# 200  392.763275  15091100        0.0           0.0  365.886076  72.366472
# 201  393.722260  13163700        0.0           0.0  367.755997  72.216553
# 202  400.594940  18742400        0.0           0.0  369.810484  73.383847
# 203  399.635986  18614700        0.0           0.0  371.795997  72.484377
#
# [184 rows x 10 columns]

# %%
from sklearn.preprocessing import MinMaxScaler
import warnings

pd.options.mode.chained_assignment = None 

# Chuẩn hóa các cột giá dựa trên tập huấn luyện và áp dụng cho tập kiểm tra và kiểm định
scaler_price = MinMaxScaler(feature_range=(-1, 1))
price_columns = ['Close', 'Open', 'High', 'Low']
data_train[price_columns] = scaler_price.fit_transform(data_train[price_columns])
data_val[price_columns] = scaler_price.transform(data_val[price_columns])
data_test_copy=data_test[price_columns]
data_test[price_columns] = scaler_price.transform(data_test[price_columns])
train_data = data_train[price_columns].values
val_data = data_val[price_columns].values
test_data = data_test[price_columns].values

# Hiển thị kích thước của các tập dữ liệu
print('Training data shape: {}'.format(train_data.shape))
print('Validation data shape: {}'.format(val_data.shape))
print('Test data shape: {}'.format(test_data.shape))
# Out:
# Training data shape: (184, 4)
# Validation data shape: (23, 4)
# Test data shape: (24, 4)

# %%
# Dữ liệu huấn luyện
seq_len = 21
X_train, y_train = [], []
for i in range(seq_len, len(train_data)):
  X_train.append(train_data[i-seq_len:i]) # Các đoạn dữ liệu huấn luyện có độ dài 21 hàng
  y_train.append(train_data[:, 0][i]) # Giá trị của cột đầu tiên (Giá đóng cửa) của hàng thứ 21+1
X_train, y_train = np.array(X_train), np.array(y_train)



# Dữ liệu kiểm định
X_val, y_val = [], []
for i in range(seq_len, len(val_data)):
    X_val.append(val_data[i-seq_len:i])
    y_val.append(val_data[:, 0][i])
X_val, y_val = np.array(X_val), np.array(y_val)


# Dữ liệu kiểm tra
X_test, y_test = [], []
for i in range(seq_len, len(test_data)):
    X_test.append(test_data[i-seq_len:i])
    y_test.append(test_data[:, 0][i])    
X_test, y_test = np.array(X_test), np.array(y_test)

print('Training set shape', X_train.shape, y_train.shape)
print('Validation set shape', X_val.shape, y_val.shape)
print('Testing set shape' ,X_test.shape, y_test.shape)
# Out:
# Training set shape (490, 21, 4) (490,)
# Validation set shape (42, 21, 4) (42,)
# Testing set shape (44, 21, 4) (44,)

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Bidirectional, LSTM, Dense
from sklearn.metrics import mean_squared_error

# Define the model
model = Sequential()
model.add(Bidirectional(LSTM(50, activation='relu', return_sequences=True), input_shape=(21, 4)))
model.add(Bidirectional(LSTM(50, activation='relu')))
model.add(Dense(1))
model.compile(optimizer='adam', loss='mean_squared_error')
model.summary()
# Out:
# c:\Users\admin\anaconda3\Lib\site-packages\keras\src\layers\rnn\bidirectional.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ bidirectional (Bidirectional)   │ (None, 21, 100)        │        22,000 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ bidirectional_1 (Bidirectional) │ (None, 100)            │        60,400 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 1)              │           101 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 82,501 (322.27 KB)
#  Trainable params: 82,501 (322.27 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
import time
start_time = time.time()
# Train the model
model.fit(X_train, y_train, epochs=100, batch_size=32, validation_data=(X_val, y_val), verbose=1)

# Predicting and reversing normalization
predicted_stock_price = model.predict(X_test)
predicted_stock_price = scaler_price.inverse_transform(np.concatenate((predicted_stock_price, np.zeros((len(predicted_stock_price), 3))), axis=1))[:,0]
end_time = time.time()
training_time = end_time - start_time
# Out:
# Epoch 1/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 28s 239ms/step - loss: 0.2059 - val_loss: 0.7815
# Epoch 2/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - loss: 0.0173 - val_loss: 0.1031
# Epoch 3/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - loss: 0.0135 - val_loss: 0.0244
# Epoch 4/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - loss: 0.0106 - val_loss: 0.0610
# Epoch 5/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 0.0074 - val_loss: 0.1432
# Epoch 6/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 51ms/step - loss: 0.0068 - val_loss: 0.7123
# Epoch 7/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - loss: 0.0058 - val_loss: 1.0679
# Epoch 8/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 52ms/step - loss: 0.0051 - val_loss: 0.2236
# Epoch 9/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - loss: 0.0069 - val_loss: 0.3200
# Epoch 10/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - loss: 0.0050 - val_loss: 0.4919
# Epoch 11/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - loss: 0.0045 - val_loss: 0.3606
# Epoch 12/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - loss: 0.0055 - val_loss: 0.2025
# Epoch 13/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - loss: 0.0049 - val_loss: 0.1488
# Epoch 14/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 60ms/step - loss: 0.0038 - val_loss: 0.2653
# Epoch 15/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 53ms/step - loss: 0.0038 - val_loss: 0.1044
# Epoch 16/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - loss: 0.0042 - val_loss: 0.1145
# Epoch 17/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - loss: 0.0043 - val_loss: 0.1558
# Epoch 18/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - loss: 0.0037 - val_loss: 0.1864
# Epoch 19/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 52ms/step - loss: 0.0030 - val_loss: 0.1780
# Epoch 20/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - loss: 0.0035 - val_loss: 0.1777
# Epoch 21/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - loss: 0.0038 - val_loss: 0.0632
# Epoch 22/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - loss: 0.0034 - val_loss: 0.0748
# Epoch 23/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 61ms/step - loss: 0.0037 - val_loss: 0.0656
# Epoch 24/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - loss: 0.0028 - val_loss: 0.0700
# Epoch 25/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - loss: 0.0031 - val_loss: 0.0475
# Epoch 26/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - loss: 0.0036 - val_loss: 0.0730
# Epoch 27/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - loss: 0.0033 - val_loss: 0.0420
# Epoch 28/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - loss: 0.0029 - val_loss: 0.0820
# Epoch 29/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - loss: 0.0029 - val_loss: 0.0524
# Epoch 30/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - loss: 0.0028 - val_loss: 0.0667
# Epoch 31/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 56ms/step - loss: 0.0026 - val_loss: 0.0536
# Epoch 32/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - loss: 0.0029 - val_loss: 0.0561
# Epoch 33/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - loss: 0.0032 - val_loss: 0.0511
# Epoch 34/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - loss: 0.0027 - val_loss: 0.0639
# Epoch 35/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - loss: 0.0026 - val_loss: 0.0360
# Epoch 36/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - loss: 0.0024 - val_loss: 0.0421
# Epoch 37/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - loss: 0.0033 - val_loss: 0.0624
# Epoch 38/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 52ms/step - loss: 0.0027 - val_loss: 0.0587
# Epoch 39/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 59ms/step - loss: 0.0027 - val_loss: 0.0476
# Epoch 40/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - loss: 0.0027 - val_loss: 0.0572
# Epoch 41/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 52ms/step - loss: 0.0025 - val_loss: 0.0490
# Epoch 42/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - loss: 0.0025 - val_loss: 0.0611
# Epoch 43/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - loss: 0.0023 - val_loss: 0.0380
# Epoch 44/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - loss: 0.0026 - val_loss: 0.0534
# Epoch 45/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - loss: 0.0025 - val_loss: 0.0356
# Epoch 46/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 0.0026 - val_loss: 0.0544
# Epoch 47/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 63ms/step - loss: 0.0027 - val_loss: 0.0368
# Epoch 48/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 51ms/step - loss: 0.0024 - val_loss: 0.0387
# Epoch 49/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 0.0027 - val_loss: 0.0516
# Epoch 50/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 51ms/step - loss: 0.0030 - val_loss: 0.0388
# Epoch 51/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 55ms/step - loss: 0.0025 - val_loss: 0.0410
# Epoch 52/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 76ms/step - loss: 0.0023 - val_loss: 0.0344
# Epoch 53/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 62ms/step - loss: 0.0026 - val_loss: 0.0442
# Epoch 54/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0026 - val_loss: 0.0498
# Epoch 55/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 0.0024 - val_loss: 0.0406
# Epoch 56/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0023 - val_loss: 0.0484
# Epoch 57/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0023 - val_loss: 0.0313
# Epoch 58/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0031 - val_loss: 0.0331
# Epoch 59/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0026 - val_loss: 0.0473
# Epoch 60/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0025 - val_loss: 0.0266
# Epoch 61/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0025 - val_loss: 0.0343
# Epoch 62/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0023 - val_loss: 0.0470
# Epoch 63/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0024 - val_loss: 0.0518
# Epoch 64/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0025 - val_loss: 0.0646
# Epoch 65/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0024 - val_loss: 0.0243
# Epoch 66/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0029 - val_loss: 0.0286
# Epoch 67/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0023 - val_loss: 0.0488
# Epoch 68/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0025 - val_loss: 0.0270
# Epoch 69/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0027 - val_loss: 0.0353
# Epoch 70/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 0.0023 - val_loss: 0.0603
# Epoch 71/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0024 - val_loss: 0.0268
# Epoch 72/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0024 - val_loss: 0.0413
# Epoch 73/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0024 - val_loss: 0.0429
# Epoch 74/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0025 - val_loss: 0.0486
# Epoch 75/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0024 - val_loss: 0.0317
# Epoch 76/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0025 - val_loss: 0.0394
# Epoch 77/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0022 - val_loss: 0.0543
# Epoch 78/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0024 - val_loss: 0.0387
# Epoch 79/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - loss: 0.0023 - val_loss: 0.0347
# Epoch 80/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0020 - val_loss: 0.0366
# Epoch 81/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0028 - val_loss: 0.0389
# Epoch 82/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0030 - val_loss: 0.0344
# Epoch 83/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0021 - val_loss: 0.0266
# Epoch 84/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0023 - val_loss: 0.0271
# Epoch 85/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0023 - val_loss: 0.0351
# Epoch 86/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0022 - val_loss: 0.0493
# Epoch 87/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0021 - val_loss: 0.0322
# Epoch 88/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 0.0024 - val_loss: 0.0265
# Epoch 89/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0022 - val_loss: 0.0497
# Epoch 90/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0027 - val_loss: 0.0352
# Epoch 91/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0022 - val_loss: 0.0382
# Epoch 92/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0019 - val_loss: 0.0382
# Epoch 93/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0024 - val_loss: 0.0593
# Epoch 94/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0020 - val_loss: 0.0396
# Epoch 95/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0024 - val_loss: 0.0561
# Epoch 96/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0021 - val_loss: 0.0508
# Epoch 97/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0026 - val_loss: 0.0495
# Epoch 98/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0023 - val_loss: 0.0710
# Epoch 99/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0018 - val_loss: 0.0445
# Epoch 100/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0020 - val_loss: 0.0416
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 3s 1s/step

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import mean_squared_error, mean_absolute_percentage_error

# Get actual prices from the last part of the test set
actual_prices = data_test_copy['Close'].values[seq_len:]

# Plotting
plt.figure(figsize=(10, 6))
plt.plot(actual_prices, color='blue', label='Actual Stock Price')
plt.plot(predicted_stock_price, color='red', label='Predicted Stock Price')
plt.title('Stock Price Prediction')
plt.xlabel('Time')
plt.ylabel('Stock Price')
plt.legend()
plt.grid(True)
plt.show()

# Calculate RMSE
rmse = mean_squared_error(actual_prices, predicted_stock_price, squared=False)
print(f"Root Mean Squared Error: {rmse}")

mape = mean_absolute_percentage_error(actual_prices, predicted_stock_price)
print(f"Mean Absolute Percentage Error: {mape}")

print('Thời gian training mô hình:',training_time)
# Out:
# Root Mean Squared Error: 47.813095342816666
# Mean Absolute Percentage Error: 0.0426553312018061
# Thời gian training mô hình: 99.7698187828064
